# %%
import numpy as np
from array import array
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import matplotlib.patches as mpatches

# %%
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'

u0lowfil = 'u_initial_low_res.dat'
v0lowfil = 'v_initial_low_res.dat'
h0lowfil = 'h_initial_low_res.dat'

Nx = 13
Ny = 5

# %%
recl = 4*Nx*Ny
u0l_bin = open(dirin+u0lowfil, 'rb')
tmpu0l = u0l_bin.read(recl)
u0l = np.reshape(array('f',tmpu0l),(Ny,Nx))

# %%
v0l_bin = open(dirin+v0lowfil, 'rb')
tmpv0l = v0l_bin.read(recl)
v0l = np.reshape(array('f',tmpv0l),(Ny,Nx))

# %%
h0l_bin = open(dirin+h0lowfil, 'rb')
tmph0l = h0l_bin.read(recl)
h0l = np.reshape(array('f',tmph0l),(Ny,Nx))

# %%
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Initial Wind (Barbs) & Height (Contours), d = 500km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
h0lc = ax.contour(x,y,h0l)
wind0l = ax.quiver(x,y,u0l,v0l,color='black',headwidth=1,headlength=3)

# %%
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'

u0medfil = 'u_initial_med_res.dat'
v0medfil = 'v_initial_med_res.dat'
h0medfil = 'h_initial_med_res.dat'

Nx = 25
Ny = 9

# %%
recl = 4*Nx*Ny
u0m_bin = open(dirin+u0medfil, 'rb')
tmpu0m = u0m_bin.read(recl)
u0m = np.reshape(array('f',tmpu0m),(Ny,Nx))

# %%
v0m_bin = open(dirin+v0medfil, 'rb')
tmpv0m = v0m_bin.read(recl)
v0m = np.reshape(array('f',tmpv0m),(Ny,Nx))

# %%
h0m_bin = open(dirin+h0medfil, 'rb')
tmph0m = h0m_bin.read(recl)
h0m = np.reshape(array('f',tmph0m),(Ny,Nx))

# %%
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Initial Wind (Barbs) & Height (Contours), d = 250km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
h0mc = ax.contour(x,y,h0m)
wind0m = ax.quiver(x,y,u0m,v0m,color='black',headwidth=1,headlength=3)

# %%
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'

u0highfil = 'u_initial_high_res.dat'
v0highfil = 'v_initial_high_res.dat'
h0highfil = 'h_initial_high_res.dat'

Nx = 49
Ny = 17

# %%
recl = 4*Nx*Ny
u0h_bin = open(dirin+u0highfil, 'rb')
tmpu0h = u0h_bin.read(recl)
u0h = np.reshape(array('f',tmpu0h),(Ny,Nx))

# %%
v0h_bin = open(dirin+v0highfil, 'rb')
tmpv0h = v0h_bin.read(recl)
v0h = np.reshape(array('f',tmpv0h),(Ny,Nx))

# %%
h0h_bin = open(dirin+h0highfil, 'rb')
tmph0h = h0h_bin.read(recl)
h0h = np.reshape(array('f',tmph0h),(Ny,Nx))

# %%
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Initial Wind (Barbs) & Height (Contours), d = 125km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
h0hc = ax.contour(x,y,h0h)
wind0h = ax.quiver(x,y,u0h,v0h,color='black',headwidth=1,headlength=3)

# %%
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'
#vor0 is 0, no need for vor0 graph#
pe0lowfil = 'pe0_initial_low_res.dat'
ke0lowfil = 'ke0_initial_low_res.dat'

Nx = 13
Ny = 5

# %%
recl = 4*Nx*Ny
pe0l_bin = open(dirin+pe0lowfil, 'rb')
tmppe0l = pe0l_bin.read(recl)
pe0l = (np.reshape(array('f',tmppe0l),(Ny,Nx)))

ke0l_bin = open(dirin+ke0lowfil, 'rb')
tmpke0l = ke0l_bin.read(recl)
ke0l = np.reshape(array('f',tmpke0l),(Ny,Nx))

te0l = pe0l + ke0l

# %%
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Initial Total Energy, d = 500km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
te0lc = ax.contour(x,y,te0l)

# %%
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'
#vor0 is 0, no need for vor0 graph#
pe0medfil = 'pe0_initial_med_res.dat'
ke0medfil = 'ke0_initial_med_res.dat'

Nx = 25
Ny = 9

# %%
recl = 4*Nx*Ny
pe0m_bin = open(dirin+pe0medfil, 'rb')
tmppe0m = pe0m_bin.read(recl)
pe0m = (np.reshape(array('f',tmppe0m),(Ny,Nx)))

ke0m_bin = open(dirin+ke0medfil, 'rb')
tmpke0m = ke0m_bin.read(recl)
ke0m = np.reshape(array('f',tmpke0m),(Ny,Nx))

te0m = pe0m + ke0m

# %%
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Initial Total Energy, d = 250km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
te0mc = ax.contourf(x,y,te0m)

# %%
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'
#vor0 is 0, no need for vor0 graph#
pe0highfil = 'pe0_initial_high_res.dat'
ke0highfil = 'ke0_initial_high_res.dat'

Nx = 49
Ny = 17

# %%
recl = 4*Nx*Ny
pe0h_bin = open(dirin+pe0highfil, 'rb')
tmppe0h = pe0h_bin.read(recl)
pe0h = (np.reshape(array('f',tmppe0h),(Ny,Nx)))

ke0h_bin = open(dirin+ke0highfil, 'rb')
tmpke0h = ke0h_bin.read(recl)
ke0h = np.reshape(array('f',tmpke0h),(Ny,Nx))

te0h = pe0h + ke0h

# %%
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Initial Total Energy, d = 125km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
te0hc = ax.contourf(x,y,te0h)

# %%
#final conditions low res
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'

ulowfil = 'u_final_low_res.dat'
vlowfil = 'v_final_low_res.dat'
hlowfil = 'h_final_low_res.dat'

pelowfil = 'pe_final_low_res.dat'
kelowfil = 'ke_final_low_res.dat'
vorlowfil = 'vor_final_low_res.dat'

Nx = 13
Ny = 5

# %%
recl = 4*Nx*Ny

#final u,v,h low res
ul_bin = open(dirin+ulowfil, 'rb')
tmpul = ul_bin.read(recl)
ul = np.reshape(array('f',tmpul),(Ny,Nx))

vl_bin = open(dirin+vlowfil, 'rb')
tmpvl = vl_bin.read(recl)
vl = np.reshape(array('f',tmpvl),(Ny,Nx))

hl_bin = open(dirin+hlowfil, 'rb')
tmphl = hl_bin.read(recl)
hl = np.reshape(array('f',tmphl),(Ny,Nx))

#final pe, ke, vor low res
pel_bin = open(dirin+pelowfil, 'rb')
tmppel = pel_bin.read(recl)
pel = np.reshape(array('f',tmppel),(Ny,Nx))

kel_bin = open(dirin+kelowfil, 'rb')
tmpkel = kel_bin.read(recl)
kel = np.reshape(array('f',tmpkel),(Ny,Nx))

vorl_bin = open(dirin+vorlowfil, 'rb')
tmpvorl = vorl_bin.read(recl)
vorl = np.reshape(array('f',tmpvorl),(Ny,Nx))

tel = pel + kel

# %%
#final u v h low res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Wind (Barbs) & Height (Contours), d = 500km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
hlc = ax.contour(x,y,hl)
windl = ax.quiver(x,y,ul,vl,color='black',headwidth=1,headlength=3)

# %%
#final pe low res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Potential Energy, d = 500km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
pelc = ax.contour(x,y,pel)

# %%
#final ke low res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Kinetic Energy, d = 500km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
kelc = ax.contour(x,y,kel)

# %%
#final te low res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Total Energy, d = 500km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
telc = ax.contour(x,y,tel)

# %%
#final vor low res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Vorticity, d = 500km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
vorlc = ax.contour(x,y,vorl)

# %%
#final conditions med res
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'

umedfil = 'u_final_med_res.dat'
vmedfil = 'v_final_med_res.dat'
hmedfil = 'h_final_med_res.dat'

pemedfil = 'pe_final_med_res.dat'
kemedfil = 'ke_final_med_res.dat'
vormedfil = 'vor_final_med_res.dat'

Nx = 25
Ny = 9

# %%
recl = 4*Nx*Ny

#final u,v,h med res
um_bin = open(dirin+umedfil, 'rb')
tmpum = um_bin.read(recl)
um = np.reshape(array('f',tmpum),(Ny,Nx))

vm_bin = open(dirin+vmedfil, 'rb')
tmpvm = vm_bin.read(recl)
vm = np.reshape(array('f',tmpvm),(Ny,Nx))

hm_bin = open(dirin+hmedfil, 'rb')
tmphm = hm_bin.read(recl)
hm = np.reshape(array('f',tmphm),(Ny,Nx))

#final pe, ke, vor med res
pem_bin = open(dirin+pemedfil, 'rb')
tmppem = pem_bin.read(recl)
pem = np.reshape(array('f',tmppem),(Ny,Nx))

kem_bin = open(dirin+kemedfil, 'rb')
tmpkem = kem_bin.read(recl)
kem = np.reshape(array('f',tmpkem),(Ny,Nx))

vorm_bin = open(dirin+vormedfil, 'rb')
tmpvorm = vorm_bin.read(recl)
vorm = np.reshape(array('f',tmpvorm),(Ny,Nx))

tem = pem + kem

# %%
#final u v h med res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Wind (Barbs) & Height (Contours), d = 250km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
hmc = ax.contour(x,y,hm)
windl = ax.quiver(x,y,um,vm,color='black',headwidth=1,headlength=3)

# %%
#final pe med res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Potential Energy, d = 250km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
pemc = ax.contour(x,y,pem)

# %%
#final ke med res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Kinetic Energy, d = 250km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
kemc = ax.contour(x,y,kem)

# %%
#final te med res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Total Energy, d = 250km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
temc = ax.contour(x,y,tem)

# %%
#final vor med res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Vorticity, d = 250km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
vormc = ax.contour(x,y,vorm)

# %%
#final conditions high res
dirin ='/home/mwestal/CLIM-470-Numerical-Weather-Prediction/Final Project/'

uhighfil = 'u_final_high_res.dat'
vhighfil = 'v_final_high_res.dat'
hhighfil = 'h_final_high_res.dat'

pehighfil = 'pe_final_high_res.dat'
kehighfil = 'ke_final_high_res.dat'
vorhighfil = 'vor_final_high_res.dat'

Nx = 49
Ny = 17

# %%
recl = 4*Nx*Ny

#final u,v,h high res
uh_bin = open(dirin+uhighfil, 'rb')
tmpuh = uh_bin.read(recl)
uh = np.reshape(array('f',tmpuh),(Ny,Nx))

vh_bin = open(dirin+vhighfil, 'rb')
tmpvh = vh_bin.read(recl)
vh = np.reshape(array('f',tmpvh),(Ny,Nx))

hh_bin = open(dirin+hhighfil, 'rb')
tmphh = hh_bin.read(recl)
hh = np.reshape(array('f',tmphh),(Ny,Nx))

#final pe, ke, vor high res
peh_bin = open(dirin+pehighfil, 'rb')
tmppeh = peh_bin.read(recl)
peh = np.reshape(array('f',tmppeh),(Ny,Nx))

keh_bin = open(dirin+kehighfil, 'rb')
tmpkeh = keh_bin.read(recl)
keh = np.reshape(array('f',tmpkeh),(Ny,Nx))

vorh_bin = open(dirin+vorhighfil, 'rb')
tmpvorh = vorh_bin.read(recl)
vorh = np.reshape(array('f',tmpvorh),(Ny,Nx))

teh = peh + keh

# %%
#final u v h high res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Wind (Barbs) & Height (Contours), d = 125km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
hhc = ax.contour(x,y,hh)
windh = ax.quiver(x,y,uh,vh,color='black',headwidth=1,headlength=3)

# %%
#final pe high res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Potential Energy, d = 125km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
pehc = ax.contour(x,y,peh)

# %%
#final ke high res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Kinetic Energy, d = 125km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
kehc = ax.contour(x,y,keh)

# %%
#final te high res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Total Energy, d = 125km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
tehc = ax.contour(x,y,teh)

# %%
#final vor high res plot
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Nx gridpoints', fontsize=16)
plt.ylabel('Ny gridpoints', fontsize=16)
plt.suptitle('Shallow Water Model Final Vorticity, d = 125km', fontsize=20)
x = np.arange(Nx)
y = np.arange(Ny)
vorhc = ax.contour(x,y,vorh)
